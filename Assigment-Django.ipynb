# %%
import PyPDF2

def extract_text_from_pdf(pdf_path):
    text = "Benign"
    with open(pdf_path, 'rb') as file:
        reader = PyPDF2.PdfFileReader(file)
        num_pages = reader.numPages
        for page_num in range(num_pages):
            page = reader.getPage(page_num)
            text += page.extractText()
    return text

# Example usage:
pdf_path =r"C:\Users\kaasi\OneDrive\Desktop\C13.pdf"  # Replace with the path to your PDF file
extracted_text = extract_text_from_pdf(pdf_path)
print(extracted_text)
# Out:
# ---------------------------------------------------------------------------
# DeprecationError                          Traceback (most recent call last)
# Cell In[6], line 15
#      13 # Example usage:
#      14 pdf_path =r"C:\Users\kaasi\OneDrive\Desktop\C13.pdf"  # Replace with the path to your PDF file
# ---> 15 extracted_text = extract_text_from_pdf(pdf_path)
#      16 print(extracted_text)
#
# Cell In[6], line 6, in extract_text_from_pdf(pdf_path)
#       4 text = "Benign"
#       5 with open(pdf_path, 'rb') as file:
# ----> 6     reader = PyPDF2.PdfFileReader(file)
#       7     num_pages = reader.numPages
#       8     for page_num in range(num_pages):
#
# File ~\anaconda3\lib\site-packages\PyPDF2\_reader.py:1974, in PdfFileReader.__init__(self, *args, **kwargs)
#    1973 def __init__(self, *args: Any, **kwargs: Any) -> None:
# -> 1974     deprecation_with_replacement("PdfFileReader", "PdfReader", "3.0.0")
#    1975     if "strict" not in kwargs and len(args) < 2:
# ...

# %%
pip install PyPDF2
# Out:
# ...
# WARNING: Error parsing requirements for sphinxcontrib-jsmath: 'utf-8' codec can't decode byte 0xbc in position 4: invalid start byte in METADATA file at path: c:\users\kaasi\anaconda3\lib\site-packages\sphinxcontrib_jsmath-1.0.1.dist-info\METADATA

# %%
import PyPDF2

def extract_text_from_pdf(pdf_path):
    text = "Benign"
    with open(pdf_path, 'rb') as file:
        reader = PyPDF2.PdfFileReader(file)
        num_pages = reader.numPages
        for page_num in range(num_pages):
            page = reader.getPage(page_num)
            text += page.extractText()
    return text

# Example usage:
pdf_path =r"C:\Users\kaasi\OneDrive\Desktop\C13.pdf"  # Replace with the path to your PDF file
extracted_text = extract_text_from_pdf(pdf_path)
print(extracted_text)
# Out:
# ---------------------------------------------------------------------------
# DeprecationError                          Traceback (most recent call last)
# Cell In[9], line 15
#      13 # Example usage:
#      14 pdf_path =r"C:\Users\kaasi\OneDrive\Desktop\C13.pdf"  # Replace with the path to your PDF file
# ---> 15 extracted_text = extract_text_from_pdf(pdf_path)
#      16 print(extracted_text)
#
# Cell In[9], line 6, in extract_text_from_pdf(pdf_path)
#       4 text = "Benign"
#       5 with open(pdf_path, 'rb') as file:
# ----> 6     reader = PyPDF2.PdfFileReader(file)
#       7     num_pages = reader.numPages
#       8     for page_num in range(num_pages):
#
# File ~\anaconda3\lib\site-packages\PyPDF2\_reader.py:1974, in PdfFileReader.__init__(self, *args, **kwargs)
#    1973 def __init__(self, *args: Any, **kwargs: Any) -> None:
# -> 1974     deprecation_with_replacement("PdfFileReader", "PdfReader", "3.0.0")
#    1975     if "strict" not in kwargs and len(args) < 2:
# ...

# %%
import PyPDF2

def extract_text_from_pdf(pdf_path):
    text = ""
    with open(pdf_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        num_pages = len(reader.pages)
        for page_num in range(num_pages):
            page = reader.pages[page_num]
            text += page.extract_text()
    return text

# Example usage:
pdf_path = r"C:\Users\kaasi\OneDrive\Desktop\C13.pdf"  # Replace with the path to your PDF file
extracted_text = extract_text_from_pdf(pdf_path)
print(extracted_text)
# Out:
#
# BENIGN  AND  MALIGNANT  DISEASE  DETECTION  USING
# DEEP  LEARNING TECHNIQUES
# A Project  Report
#
# Submitted  to the Faculty  of Engineering  of
# JAWAHARLAL  NEHRU  TECHNOLOGICAL  UNIVERSITY  KAKINADA,
# KAKINADA
# In partial  fulfillment  of the requirements for the award  of the Degree  of
#
# BACHELOR  OF TECHNOLOGY
# In
# COMPUTER  SCIENCE  AND  ENGINEERING
#
# By
# M. KAASI REDDY  M. BINDU  SRIHITHA
# (20481A05G5)   (20481A05E4)
#
# P. GEETHA  NAGA  DEVI  PRIYA  M. RAVI  KISHORE
# (20481A05I6)   (20481A05E9)
#
#
# Under  the guidance  of
# Mr. M. N. SATISH  KUMAR,  M. Tech  (Ph. D)
# Assistant  Professor  of CSE Department
#
#
#
#
#
#
#
#
# DEPARTMENT  OF COMPUTER  SCIENCE  AND  ENGINEERING
# SESHADRI  RAO  GUDLAVALLERU  ENGINEERING  COLLEGE
# (An Autonomous  Institute  with  Permanent  Affiliation  to JNTUK,  Kakinada)
# SESHADRI  RAO  KNOWLEDGE  VILLAGE
# GUDLAVALLERU  – 521356
# ANDHRA  PRADESH
# 2023 -2024  SESHADRI  RAO  GUDLAVALLERU  ENGINEERING  COLLEGE
# ...
